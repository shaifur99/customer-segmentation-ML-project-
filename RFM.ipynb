# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('OnlineRetail.csv', encoding='unicode_escape')

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#             InvoiceDate  UnitPrice  CustomerID         Country
# 0        12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2        12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3        12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4        12/1/2010 8:26       3.39     17850.0  United Kingdom
# ...                 ...        ...         ...             ...
# 541904  12/9/2011 12:50       0.85     12680.0          France
# 541905  12/9/2011 12:50       2.10     12680.0          France
# 541906  12/9/2011 12:50       4.15     12680.0          France
# 541907  12/9/2011 12:50       4.15     12680.0          France
# 541908  12/9/2011 12:50       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %%
df.tail(5)

# %%
currentDate = pd.to_datetime("2012-01-01")

df['InvoiceDate']=pd.to_datetime(df["InvoiceDate"])

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France
# 541905 2011-12-09 12:50:00       2.10     12680.0          France
# 541906 2011-12-09 12:50:00       4.15     12680.0          France
# 541907 2011-12-09 12:50:00       4.15     12680.0          France
# 541908 2011-12-09 12:50:00       4.95     12680.0          France
#
# [541909 rows x 8 columns]

# %%
currentDate
# Out:
# Timestamp('2012-01-01 00:00:00')

# %%
df.dtypes
# Out:
# InvoiceNo              object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# UnitPrice             float64
# CustomerID            float64
# Country                object
# dtype: object

# %%
maxdate = df.groupby(["CustomerID"]).max()[['InvoiceDate']]
maxdate
# Out:
#                    InvoiceDate
# CustomerID
# 12346.0    2011-01-18 10:17:00
# 12347.0    2011-12-07 15:52:00
# 12348.0    2011-09-25 13:13:00
# 12349.0    2011-11-21 09:51:00
# 12350.0    2011-02-02 16:01:00
# ...                        ...
# 18280.0    2011-03-07 09:52:00
# 18281.0    2011-06-12 10:53:00
# 18282.0    2011-12-02 11:43:00
# 18283.0    2011-12-06 12:02:00
# 18287.0    2011-10-28 09:29:00
#
# [4372 rows x 1 columns]

# %%
(currentDate - maxdate['InvoiceDate']).dt.days
# Out:
# CustomerID
# 12346.0    347
# 12347.0     24
# 12348.0     97
# 12349.0     40
# 12350.0    332
#           ...
# 18280.0    299
# 18281.0    202
# 18282.0     29
# 18283.0     25
# 18287.0     64
# Name: InvoiceDate, Length: 4372, dtype: int64

# %%
maxdate['InvoiceAge'] = (currentDate - maxdate['InvoiceDate']).dt.days
maxdate
# Out:
#                    InvoiceDate  InvoiceAge
# CustomerID
# 12346.0    2011-01-18 10:17:00         347
# 12347.0    2011-12-07 15:52:00          24
# 12348.0    2011-09-25 13:13:00          97
# 12349.0    2011-11-21 09:51:00          40
# 12350.0    2011-02-02 16:01:00         332
# ...                        ...         ...
# 18280.0    2011-03-07 09:52:00         299
# 18281.0    2011-06-12 10:53:00         202
# 18282.0    2011-12-02 11:43:00          29
# 18283.0    2011-12-06 12:02:00          25
# 18287.0    2011-10-28 09:29:00          64
#
# [4372 rows x 2 columns]

# %%
#recenccy

recency = maxdate.drop('InvoiceDate', axis=1)
recency
# Out:
#             InvoiceAge
# CustomerID
# 12346.0            347
# 12347.0             24
# 12348.0             97
# 12349.0             40
# 12350.0            332
# ...                ...
# 18280.0            299
# 18281.0            202
# 18282.0             29
# 18283.0             25
# 18287.0             64
#
# [4372 rows x 1 columns]

# %%
freq = df.drop_duplicates(subset="InvoiceNo")
freq
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 7         536366     22633               HAND WARMER UNION JACK         6
# 9         536367     84879        ASSORTED COLOUR BIRD ORNAMENT        32
# 21        536368     22960             JAM MAKING SET WITH JARS         6
# 25        536369     21756             BATH BUILDING BLOCK WORD         3
# ...          ...       ...                                  ...       ...
# 541865    581583     20725              LUNCH BAG RED RETROSPOT        40
# 541867    581584     20832     RED FLOCK LOVE HEART PHOTO FRAME        72
# 541869    581585     22481       BLACK TEA TOWEL CLASSIC DESIGN        12
# 541890    581586     22061  LARGE CAKE STAND  HANGING STRAWBERY         8
# 541894    581587     22631             CIRCUS PARADE LUNCH BOX         12
#
#                InvoiceDate  UnitPrice  CustomerID         Country
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom
# 7      2010-12-01 08:28:00       1.85     17850.0  United Kingdom
# 9      2010-12-01 08:34:00       1.69     13047.0  United Kingdom
# 21     2010-12-01 08:34:00       4.25     13047.0  United Kingdom
# 25     2010-12-01 08:35:00       5.95     13047.0  United Kingdom
# ...                    ...        ...         ...             ...
# 541865 2011-12-09 12:23:00       1.45     13777.0  United Kingdom
# 541867 2011-12-09 12:25:00       0.72     13777.0  United Kingdom
# 541869 2011-12-09 12:31:00       0.39     15804.0  United Kingdom
# 541890 2011-12-09 12:49:00       2.95     13113.0  United Kingdom
# 541894 2011-12-09 12:50:00       1.95     12680.0          France
#
# [25900 rows x 8 columns]

# %%
freq2 = freq.groupby(["CustomerID"]).count()[["InvoiceNo"]]
freq2
# Out:
#             InvoiceNo
# CustomerID
# 12346.0             2
# 12347.0             7
# 12348.0             4
# 12349.0             1
# 12350.0             1
# ...               ...
# 18280.0             1
# 18281.0             1
# 18282.0             3
# 18283.0            16
# 18287.0             3
#
# [4372 rows x 1 columns]

# %%
#monetary
df["total"]=df["Quantity"]*df["UnitPrice"]

# %%
df
# Out:
#        InvoiceNo StockCode                          Description  Quantity  \
# 0         536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1         536365     71053                  WHITE METAL LANTERN         6
# 2         536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3         536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4         536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...          ...       ...                                  ...       ...
# 541904    581587     22613          PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138        BAKING SET 9 PIECE RETROSPOT          3
#
#                InvoiceDate  UnitPrice  CustomerID         Country  total
# 0      2010-12-01 08:26:00       2.55     17850.0  United Kingdom  15.30
# 1      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 2      2010-12-01 08:26:00       2.75     17850.0  United Kingdom  22.00
# 3      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# 4      2010-12-01 08:26:00       3.39     17850.0  United Kingdom  20.34
# ...                    ...        ...         ...             ...    ...
# 541904 2011-12-09 12:50:00       0.85     12680.0          France  10.20
# 541905 2011-12-09 12:50:00       2.10     12680.0          France  12.60
# 541906 2011-12-09 12:50:00       4.15     12680.0          France  16.60
# 541907 2011-12-09 12:50:00       4.15     12680.0          France  16.60
# 541908 2011-12-09 12:50:00       4.95     12680.0          France  14.85
#
# [541909 rows x 9 columns]

# %%
money=df.groupby(["CustomerID"])[["total"]].sum()
money
# Out:
#               total
# CustomerID
# 12346.0        0.00
# 12347.0     4310.00
# 12348.0     1797.24
# 12349.0     1757.55
# 12350.0      334.40
# ...             ...
# 18280.0      180.60
# 18281.0       80.82
# 18282.0      176.60
# 18283.0     2094.88
# 18287.0     1837.28
#
# [4372 rows x 1 columns]

# %%
df[df['CustomerID']==12346.0]
# Out:
#       InvoiceNo StockCode                     Description  Quantity  \
# 61619    541431     23166  MEDIUM CERAMIC TOP STORAGE JAR     74215
# 61624   C541433     23166  MEDIUM CERAMIC TOP STORAGE JAR    -74215
#
#               InvoiceDate  UnitPrice  CustomerID         Country    total
# 61619 2011-01-18 10:01:00       1.04     12346.0  United Kingdom  77183.6
# 61624 2011-01-18 10:17:00       1.04     12346.0  United Kingdom -77183.6

# %%
RFM = pd.concat([recency,freq2,money], axis=1)
RFM
# Out:
#             InvoiceAge  InvoiceNo    total
# CustomerID
# 12346.0            347          2     0.00
# 12347.0             24          7  4310.00
# 12348.0             97          4  1797.24
# 12349.0             40          1  1757.55
# 12350.0            332          1   334.40
# ...                ...        ...      ...
# 18280.0            299          1   180.60
# 18281.0            202          1    80.82
# 18282.0             29          3   176.60
# 18283.0             25         16  2094.88
# 18287.0             64          3  1837.28
#
# [4372 rows x 3 columns]

# %%
RFM.columns = ['Recency', 'Frequency', 'Monetary']
RFM
# Out:
#             Recency  Frequency  Monetary
# CustomerID
# 12346.0         347          2      0.00
# 12347.0          24          7   4310.00
# 12348.0          97          4   1797.24
# 12349.0          40          1   1757.55
# 12350.0         332          1    334.40
# ...             ...        ...       ...
# 18280.0         299          1    180.60
# 18281.0         202          1     80.82
# 18282.0          29          3    176.60
# 18283.0          25         16   2094.88
# 18287.0          64          3   1837.28
#
# [4372 rows x 3 columns]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled = scaler.fit_transform(RFM)

# %%
scaled
# Out:
# array([[ 2.31656788, -0.32936215, -0.23100099],
#        [-0.88904975,  0.20610242,  0.29343167],
#        [-0.16456032, -0.11517632, -0.01231622],
#        ...,
#        [-0.83942719, -0.22226923, -0.20951263],
#        [-0.87912524,  1.16993863,  0.02390005],
#        [-0.49206924, -0.22226923, -0.00744423]])

# %%
scaled.shape
# Out:
# (4372, 3)

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# ### To find out the value of K

# %%
k_range = range(2,11)
sse = []
for k in k_range:
    km = KMeans(n_clusters = k) 
    km.fit(scaled)
    sse.append(km.inertia_)

# %%
sse
# Out:
# [9424.390666475232,
#  5530.959561618621,
#  4081.8960970338676,
#  3038.2506451982963,
#  2588.4253535218745,
#  2026.6086538528427,
#  1697.2085693941735,
#  1437.814857845874,
#  1248.379277144418]

# %%
plt.plot(k_range, sse, 'r-*')
plt.xlabel ='k'
plt.ylabel = 'Sum of Squared Error'

# %%
#pip install yellowbrick

# %%
from yellowbrick.cluster import KElbowVisualizer
Elbow = KElbowVisualizer(KMeans(), k=10)
Elbow.fit(scaled)
Elbow.show()
# Out:
# <Axes: title={'center': 'Distortion Score Elbow for KMeans Clustering'}, xlabel='k', ylabel='distortion score'>

# %% [markdown]
# ### Object Creation and data fitting

# %%
kmeans = KMeans(n_clusters=5) #, random_state=42)
kmeans.fit(scaled)
# Out:
# KMeans(n_clusters=5)

# %%
kmeans.labels_
# Out:
# array([2, 3, 3, ..., 3, 0, 3])

# %%
kmeans.labels_.shape
# Out:
# (4372,)

# %%
RFM["Clusters"]=(kmeans.labels_)

# %%
RFM
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12346.0         347          2      0.00         2
# 12347.0          24          7   4310.00         3
# 12348.0          97          4   1797.24         3
# 12349.0          40          1   1757.55         3
# 12350.0         332          1    334.40         2
# ...             ...        ...       ...       ...
# 18280.0         299          1    180.60         2
# 18281.0         202          1     80.82         2
# 18282.0          29          3    176.60         3
# 18283.0          25         16   2094.88         0
# 18287.0          64          3   1837.28         3
#
# [4372 rows x 4 columns]

# %%
RFM.Clusters.unique()
# Out:
# array([2, 3, 0, 1, 4])

# %%
fig = plt.figure(figsize=(10,8))
ax = plt.subplot(111, projection='3d', label="bla")
#ax.scatter(RFM["Recency"],RFM["Frequency"],RFM["Monetary"], s=40, marker='o', cmap = "Accent")
ax.scatter(RFM["Recency"],RFM["Frequency"],RFM["Monetary"], s=40, c=RFM["Clusters"], marker='o', cmap = "Accent")
ax.set_title("The Plot Of The Clusters")
plt.show()

# %%
RFM[RFM.Clusters==0]
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12362.0          25         13   5154.58         0
# 12395.0          37         15   2998.28         0
# 12417.0          25         12   3578.80         0
# 12428.0          47         12   7877.20         0
# 12431.0          57         18   6416.39         0
# ...             ...        ...       ...       ...
# 18225.0          25         17   5361.02         0
# 18226.0          60         14   5192.10         0
# 18229.0          33         20   7276.90         0
# 18241.0          31         18   2058.09         0
# 18283.0          25         16   2094.88         0
#
# [365 rows x 4 columns]

# %%
RFM[RFM.Clusters==1]
# Out:
#             Recency  Frequency   Monetary  Clusters
# CustomerID
# 12415.0          46         26  123725.45         1
# 14646.0          23         77  279489.02         1
# 17450.0          30         55  187482.17         1
# 18102.0          22         62  256438.49         1

# %%
RFM[RFM.Clusters==2]
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12346.0         347          2      0.00         2
# 12350.0         332          1    334.40         2
# 12353.0         226          1     89.00         2
# 12354.0         254          1   1079.40         2
# 12355.0         236          1    459.40         2
# ...             ...        ...       ...       ...
# 18256.0         376          1    -50.10         2
# 18260.0         194          8   2595.00         2
# 18269.0         380          2    138.90         2
# 18280.0         299          1    180.60         2
# 18281.0         202          1     80.82         2
#
# [1071 rows x 4 columns]

# %%
RFM[RFM.Clusters==3]
# Out:
#             Recency  Frequency  Monetary  Clusters
# CustomerID
# 12347.0          24          7   4310.00         3
# 12348.0          97          4   1797.24         3
# 12349.0          40          1   1757.55         3
# 12352.0          58         11   1545.41         3
# 12356.0          44          3   2811.43         3
# ...             ...        ...       ...       ...
# 18276.0          43          3    323.36         3
# 18277.0          80          2     97.63         3
# 18278.0          95          1    173.90         3
# 18282.0          29          3    176.60         3
# 18287.0          64          3   1837.28         3
#
# [2911 rows x 4 columns]

# %%
RFM[RFM.Clusters==4]
# Out:
#             Recency  Frequency   Monetary  Clusters
# CustomerID
# 12748.0          22        224   29072.10         4
# 12971.0          25         89   10930.26         4
# 13089.0          24        118   57385.88         4
# 13408.0          23         81   27487.41         4
# 13694.0          25         60   62653.10         4
# 13798.0          23         63   36351.42         4
# 14096.0          26         34   57120.91         4
# 14156.0          31         66  113384.14         4
# 14298.0          25         45   50862.44         4
# 14527.0          24         86    7711.38         4
# 14606.0          23        128   11713.85         4
# 14911.0          23        248  132572.62         4
# 15061.0          25         55   54228.74         4
# 15311.0          22        118   59419.34         4
# 16013.0          25         54   33366.25         4
# 16029.0          60         76   50992.61         4
# 16422.0          39         75   33805.69         4
# 16684.0          26         31   65892.08         4
# 17511.0          24         46   88125.38         4
# 17841.0          23        169   40340.78         4
# 17949.0          23         52   52750.84         4

# %%
final=RFM.groupby("Clusters").mean()[["Recency","Frequency","Monetary"]]
final
# Out:
#              Recency  Frequency       Monetary
# Clusters
# 0          36.320548  19.652055    7095.058137
# 1          30.250000  55.000000  211783.782500
# 2         271.043884   1.802988     453.748096
# 3          66.076950   3.760907    1134.009974
# 4          26.714286  91.333333   51246.058095

# %%
def func(row):
    if row["Clusters"]==2:
        return 'E Grade'
    elif row["Clusters"]==3:
        return 'D Grade'
    elif row["Clusters"]==0:
        return 'Silver'
    elif row["Clusters"]==4:
        return 'Gold'
    else:
        return 'Diamond'

# %%
RFM['group']=RFM.apply(func, axis=1)

# %%
RFM
# Out:
#             Recency  Frequency  Monetary  Clusters    group
# CustomerID
# 12346.0         347          2      0.00         2  E Grade
# 12347.0          24          7   4310.00         3  D Grade
# 12348.0          97          4   1797.24         3  D Grade
# 12349.0          40          1   1757.55         3  D Grade
# 12350.0         332          1    334.40         2  E Grade
# ...             ...        ...       ...       ...      ...
# 18280.0         299          1    180.60         2  E Grade
# 18281.0         202          1     80.82         2  E Grade
# 18282.0          29          3    176.60         3  D Grade
# 18283.0          25         16   2094.88         0   Silver
# 18287.0          64          3   1837.28         3  D Grade
#
# [4372 rows x 5 columns]

# %%
result = pd.DataFrame(RFM.group.value_counts())

# %%
result = result.reset_index()
result
# Out:
#      group  count
# 0  D Grade   2911
# 1  E Grade   1071
# 2   Silver    365
# 3     Gold     21
# 4  Diamond      4

# %%
import seaborn as sns

# %%
datalabel=sns.barplot(x="group", y="count", data=result, estimator=np.sum)
for i in datalabel.containers:
    datalabel.bar_label(i,)

# %%
ABC = RFM[RFM.Clusters==2]

# %%
ABC[ABC['Monetary']==ABC['Monetary'].min()]

# %%
ABC[ABC['Monetary']==ABC['Monetary'].max()]

# %%
ABC = RFM[RFM.Clusters==0]
ABC[ABC['Monetary']==ABC['Monetary'].max()]
